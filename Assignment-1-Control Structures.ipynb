# %%
print("Welcome to Assignment-1")
# Out:
# Welcome to Assignment-1

# %%
Num1=int(input("Num1="))
Num2=int(input("Num2="))
Add=print("Add=",Num1+Num2)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
Num1=10
Num2=30
Add=Num1+Num2
print("Num1=",Num1)
print("Num2=",Num2)
print("Add=",Add)
# Out:
# Num1= 10
# Num2= 30
# Add= 40

# %%
BMI=int(input("Enter the BMI Index:"))
if(BMI<18):
    print("Beloe normal weight")
elif(BMI>=18 and BMI<25):
    print("Normal weight")
elif(BMI>=25 and BMI<30):
    print("Over Weight")
elif(BMI>=30 and BMI<35):
    print("Very over weight or class1 Obesity")
elif(BMI>=35 and BMI<40):
    print("Obesity class2")
else:
    print("obesity calss3")
# Out:
# Enter the BMI Index: 34
# Very over weight or class1 Obesity
